# %%
# !git clone https://github.com/pola-rs/polars.git
# Out:
# Cloning into 'polars'...
# remote: Enumerating objects: 244254, done.
# remote: Counting objects: 100% (281/281), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 244254 (delta 231), reused 193 (delta 193), pack-reused 243973 (from 2)
# Receiving objects: 100% (244254/244254), 192.06 MiB | 8.64 MiB/s, done.
# Resolving deltas: 100% (195389/195389), done.

# %%
# %cd /content/polars
# Out:
# /content/polars

# %%
# !git shortlog -sn --email --no-merges | head -n 20 | tee users-commit.txt
# Out:
#   4825	Ritchie Vink <ritchie46@gmail.com>
#    994	ritchie46 <ritchie46@gmail.com>
#    878	Alexander Beedie <alexander-beedie@users.noreply.github.com>
#    609	Stijn de Gooijer <stijndegooijer@gmail.com>
#    597	Stijn de Gooijer <stijn@degooijer.io>
#    404	Orson Peters <orsonpeters@gmail.com>
#    392	nameexhaustion <simonlin.rqmmw@slmail.me>
#    374	Gijs Burghoorn <me@gburghoorn.com>
#    325	Marco Edward Gorelli <marcogorelli@protonmail.com>
#    231	Weijie Guo <reswqa@163.com>
#    157	dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>
#    155	J van Zundert <mail@jeroenvanzundert.nl>
#    149	Marshall <mcrumiller@users.noreply.github.com>
#    131	Gert Hulselmans <hulselmansgert@gmail.com>
#    115	Marco Edward Gorelli <33491632+MarcoGorelli@users.noreply.github.com>
#     81	Luke Manley <lukemanley@gmail.com>
#     66	universalmind303 <universalmind.candy@gmail.com>
#     62	chielP <chielpeters@live.nl>
# ...

# %%
# !git log --shortstat --pretty="%H" --since="1 year ago" --author="Ritchie Vink" --no-merges | awk '/files changed/ {inserted+=$4; deleted+=$6} END {print "Inserções: " inserted "\nExclusões: " deleted}'
# Out:
# Inserções: 46251
# Exclusões: 29680

# %%
# !pip install git-bars
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for git-bars: filename=git_bars-1.7-py3-none-any.whl size=3557 sha256=7b3078870e24aa91796ca54b03c26d10e7f608fb26cd877af27c644aebb9fd91
#   Stored in directory: /root/.cache/pip/wheels/3e/b2/87/a8e9107cb3d1caa3478e7026211cfa245bce4ca6a6daeff211
# Successfully built git-bars
# ...

# %%
# !git-bars -p day -u "ritchie46@gmail.com"
# Out:
# 5834 commits over 1465 day(s)
# 2025-04-21  1    ▀▀
# 2025-04-20  1    ▀▀
# 2025-04-19  3    ▀▀▀▀▀▀▀▀
# 2025-04-18  2    ▀▀▀▀▀
# 2025-04-17  2    ▀▀▀▀▀
# 2025-04-14  1    ▀▀
# 2025-04-13  1    ▀▀
# 2025-04-11  2    ▀▀▀▀▀
# 2025-04-09  2    ▀▀▀▀▀
# 2025-04-01  1    ▀▀
# 2025-03-31  1    ▀▀
# 2025-03-29  1    ▀▀
# 2025-03-28  2    ▀▀▀▀▀
# 2025-03-24  1    ▀▀
# 2025-03-22  1    ▀▀
# 2025-03-19  2    ▀▀▀▀▀
# 2025-03-18  1    ▀▀
# 2025-03-17  1    ▀▀
# 2025-03-16  1    ▀▀
# 2025-03-15  3    ▀▀▀▀▀▀▀▀
# 2025-03-14  3    ▀▀▀▀▀▀▀▀
# 2025-03-13  1    ▀▀
# 2025-03-12  3    ▀▀▀▀▀▀▀▀
# 2025-03-11  5    ▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2025-03-10  1    ▀▀
# 2025-03-09  1    ▀▀
# 2025-03-08  1    ▀▀
# 2025-03-07  6    ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2025-03-06  8    ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2025-03-05  2    ▀▀▀▀▀
# 2025-03-03  3    ▀▀▀▀▀▀▀▀
# 2025-03-02  2    ▀▀▀▀▀
# 2025-03-01  3    ▀▀▀▀▀▀▀▀
# 2025-02-28  3    ▀▀▀▀▀▀▀▀
# 2025-02-27  3    ▀▀▀▀▀▀▀▀
# 2025-02-25  3    ▀▀▀▀▀▀▀▀
# 2025-02-23  3    ▀▀▀▀▀▀▀▀
# 2025-02-22  2    ▀▀▀▀▀
# ...

# %%
# !git-bars -p month -a '2023-05-01'  -u "ritchie46@gmail.com"
# Out:
# 1475 commits over 24 month(s)
# 2025-04  16   ▀▀▀▀▀▀▀▀
# 2025-03  53   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2025-02  41   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2025-01  47   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-12  42   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-11  42   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-10  49   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-09  39   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-08  49   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-07  60   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-06  94   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-05  80   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-04  77   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-03  73   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-02  51   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-01  66   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-12  51   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-11  87   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-10  81   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-09  66   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# ...

# %%
# !git log --author="Ritchie Vink" --name-only --pretty=format: | sort | uniq
# Out:
# Cargo.lock
# Cargo.toml
# CHANGELOG.md
# CODE_OF_CONDUCT.md
# CONTRIBUTING.md
# contribution/polars_ops_multiple_arguments/Cargo.toml
# contribution/polars_ops_multiple_arguments/src/lib.rs
# contribution/README.md
# crates/Makefile
# crates/nano-arrow/Cargo.toml
# crates/nano-arrow/src/array/binary/data.rs
# crates/nano-arrow/src/array/binary/ffi.rs
# crates/nano-arrow/src/array/binary/fmt.rs
# crates/nano-arrow/src/array/binary/from.rs
# crates/nano-arrow/src/array/binary/iterator.rs
# crates/nano-arrow/src/array/binary/mod.rs
# crates/nano-arrow/src/array/binary/mutable.rs
# crates/nano-arrow/src/array/binary/mutable_values.rs
# crates/nano-arrow/src/array/boolean/data.rs
# crates/nano-arrow/src/array/boolean/ffi.rs
# crates/nano-arrow/src/array/boolean/fmt.rs
# crates/nano-arrow/src/array/boolean/from.rs
# crates/nano-arrow/src/array/boolean/iterator.rs
# crates/nano-arrow/src/array/boolean/mod.rs
# crates/nano-arrow/src/array/boolean/mutable.rs
# ...

# %%
# !pip install radon
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# !git log --pretty=format: --name-only --no-merges | sort | uniq -c | sort -nr | head -20 | tee files-churn.txt
# Out:
#   12381
#     763 py-polars/Cargo.toml
#     734 py-polars/Cargo.lock
#     590 py-polars/polars/dataframe/frame.py
#     415 py-polars/src/dataframe.rs
#     404 py-polars/polars/series/series.py
#     397 py-polars/polars/lazyframe/frame.py
#     396 py-polars/polars/expr/expr.py
#     350 polars/polars-core/Cargo.toml
#     343 py-polars/src/lazy/dsl.rs
#     342 Cargo.lock
#     339 py-polars/src/series.rs
#     336 polars/Cargo.toml
#     309 py-polars/tests/test_df.py
#     298 Cargo.toml
#     291 polars/polars-core/src/frame/mod.rs
#     272 py-polars/src/lib.rs
#     261 polars/polars-io/Cargo.toml
#     257 py-polars/tests/test_series.py
#     255 polars/polars-core/src/series/mod.rs

# %%
# !radon cc src -a -nc
