# %% [markdown]
# # Informação básicas

# %% [markdown]
# Baixando o repositório desejado

# %%
# !git clone https://github.com/pandas-dev/pandas.git
# Out:
# Cloning into 'pandas'...
# remote: Enumerating objects: 406583, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 406583 (delta 1), reused 0 (delta 0), pack-reused 406572 (from 2)
# Receiving objects: 100% (406583/406583), 358.18 MiB | 17.53 MiB/s, done.
# Resolving deltas: 100% (342037/342037), done.

# %%
# %cd /content/pandas
# Out:
# /content/pandas

# %%
# !git log --format='%aN' | sort -u | tee users.txt
# Out:
# 1_x7
# 21CSM
# 3553x
# 3vts
# 3w36zj6
# 5j9
# Aadharsh-Acharya
# Aadhi Manivannan
# Aaditya Panikath
# Aarni Koskela
# aaron315
# Aaron Barber
# aaronchucarroll
# Aaron Critchley
# Aaron Rahman
# aaron-robeson-8451
# Aaron Schumacher
# Aaron Staple
# Aaron Toth
# Aashish KC
# abaldenko
# abarber4gh
# Abbie Popa
# ABCPAN-rank
# AbdealiJK
# Abdulaziz Aloqeely
# Abdullah Ihsan Secer
# Abdullah İhsan Seçer
# AbdulMAbdi
# Abel Tavares
# aberres
# Abhijeet Krishnan
# Abhijit Deo
# Abhinav Reddy
# Abhiraj Hinge
# Abhishek Chaudhari
# Abhishek Mangla
# Abhishek R
# abmyii
# Abo7atm
# abokey1
# abonte
# Abraham Flaxman
# A Brooks
# Acanthostega
# Achmad Syarif Hidayatullah
# acorbe
# Ada Draginda
# Adam Bowden
# Adam Bull
# Adam Chainz
# Adam Gleave
# Adam Greenhall
# Adam Hooper
# Adam J. Stewart
# Adam Kim
# Adam Klaum
# Adam Klein
# Adam Klimont
# Ádám Lippai
# Adam Marcus
# Adam Mróz
# Adam Obeng
# Adam Ormondroyd
# AdamShamlian
# Adam Smith
# Adam Spannbauer
# Adam Turner
# ...

# %% [markdown]
# Lista contribuidores

# %%
# !git shortlog -s | tee commits.txt
# Out:
#      1	1_x7
#      1	21CSM
#      1	3553x
#      9	3vts
#      1	3w36zj6
#      1	5j9
#      1	A Brooks
#      1	A. Flaxman
#      2	ABCPAN-rank
#      5	AG
#      1	AJ Dyka
#      1	AJ Pryor, Ph.D
#      1	ARF
#      1	Aadharsh-Acharya
#      1	Aadhi Manivannan
#      3	Aaditya Panikath
#      6	Aarni Koskela
#      1	Aaron Barber
#     10	Aaron Critchley
#      1	Aaron Rahman
#      1	Aaron Schumacher
#      2	Aaron Staple
#      1	Aaron Toth
#      1	Aashish KC
#      1	Abbie Popa
#      1	AbdealiJK
#      1	AbdulMAbdi
#     34	Abdulaziz Aloqeely
#      3	Abdullah Ihsan Secer
#     15	Abdullah İhsan Seçer
#      4	Abel Tavares
#      3	Abhijeet Krishnan
#      1	Abhijit Deo
#      5	Abhinav Reddy
#      1	Abhiraj Hinge
#      2	Abhishek Chaudhari
#      2	Abhishek Mangla
#      1	Abhishek R
#      1	Abo7atm
#     19	Abraham Flaxman
#      1	Acanthostega
#      2	Achmad Syarif Hidayatullah
#      1	Ada Draginda
#      1	Adam Bowden
#      2	Adam Bull
#      1	Adam Chainz
# ...

# %%
# !git shortlog -sn --email --no-merges | head -n 20 | tee users-commit.txt
# Out:
#   4841	jbrockmendel <jbrockmendel@gmail.com>
#   2984	Wes McKinney <wesmckinn@gmail.com>
#   1398	jreback <jeff@reback.net>
#   1349	Jeff Reback <jeff@reback.net>
#   1143	Joris Van den Bossche <jorisvandenbossche@gmail.com>
#    947	Patrick Hoefler <61934744+phofl@users.noreply.github.com>
#    765	y-p <yoval@gmx.com>
#    707	Matthew Roeschke <emailformattr@gmail.com>
#    698	Matthew Roeschke <10647082+mroeschke@users.noreply.github.com>
#    622	Simon Hawkins <simonjayhawkins@gmail.com>
#    586	Tom Augspurger <TomAugspurger@users.noreply.github.com>
#    420	Richard Shadrach <45562402+rhshadrach@users.noreply.github.com>
#    394	Phillip Cloud <cpcloud@gmail.com>
#    359	Chang She <chang@lambdafoundry.com>
#    349	gfyoung <gfyoung17@gmail.com>
#    344	sinhrks <sinhrks@gmail.com>
#    315	Adam Klein <adamklein@gmail.com>
#    309	Tuhin Sharma <tuhinsharma121@gmail.com>
#    261	Marc Garcia <garcia.marc@gmail.com>
# ...

# %%
# !git log --shortstat --pretty="%H" --since="1 year ago" --author="jbrockmendel" --no-merges | awk '/files changed/ {inserted+=$4; deleted+=$6} END {print "Inserções: " inserted "\nExclusões: " deleted}'
# Out:
# Inserções: 2071
# Exclusões: 1891

# %%
# !pip install git-bars
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for git-bars: filename=git_bars-1.7-py3-none-any.whl size=3557 sha256=7efb88b930ac5edf4cb12390ee8fdb05ec67770c5348444b3a2ebff99bbee9d8
#   Stored in directory: /root/.cache/pip/wheels/3e/b2/87/a8e9107cb3d1caa3478e7026211cfa245bce4ca6a6daeff211
# Successfully built git-bars
# ...

# %%
# !git-bars -p day -u "jbrockmendel@gmail.com"
# Out:
# 4844 commits over 1441 day(s)
# 2025-01-30  1    ▀▀
# 2024-11-08  1    ▀▀
# 2024-11-04  1    ▀▀
# 2024-09-25  2    ▀▀▀▀▀
# 2024-09-11  1    ▀▀
# 2024-09-10  1    ▀▀
# 2024-09-06  1    ▀▀
# 2024-09-05  1    ▀▀
# 2024-09-04  3    ▀▀▀▀▀▀▀
# 2024-09-02  1    ▀▀
# 2024-08-31  1    ▀▀
# 2024-08-29  1    ▀▀
# 2024-08-28  3    ▀▀▀▀▀▀▀
# 2024-08-27  2    ▀▀▀▀▀
# 2024-08-22  1    ▀▀
# 2024-08-16  1    ▀▀
# 2024-08-15  2    ▀▀▀▀▀
# 2024-08-14  1    ▀▀
# 2024-08-13  2    ▀▀▀▀▀
# 2024-08-09  2    ▀▀▀▀▀
# 2024-08-07  1    ▀▀
# 2024-06-04  1    ▀▀
# 2024-05-31  1    ▀▀
# 2024-05-08  1    ▀▀
# 2024-04-29  2    ▀▀▀▀▀
# 2024-04-24  2    ▀▀▀▀▀
# 2024-04-23  1    ▀▀
# 2024-04-19  1    ▀▀
# 2024-04-14  1    ▀▀
# 2024-04-12  1    ▀▀
# 2024-04-08  1    ▀▀
# 2024-04-05  4    ▀▀▀▀▀▀▀▀▀▀
# 2024-04-01  1    ▀▀
# 2024-03-29  6    ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-03-28  2    ▀▀▀▀▀
# 2024-03-27  4    ▀▀▀▀▀▀▀▀▀▀
# 2024-03-26  6    ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-03-25  3    ▀▀▀▀▀▀▀
# 2024-03-18  1    ▀▀
# 2024-02-27  2    ▀▀▀▀▀
# ...

# %%
# !git-bars -p month -a '2023-05-01'  -u "jbrockmendel@gmail.com"
# Out:
# 409 commits over 18 month(s)
# 2025-01  1
# 2024-11  2    ▀
# 2024-09  10   ▀▀▀▀▀
# 2024-08  17   ▀▀▀▀▀▀▀▀▀
# 2024-06  1
# 2024-05  2    ▀
# 2024-04  14   ▀▀▀▀▀▀▀▀
# 2024-03  22   ▀▀▀▀▀▀▀▀▀▀▀▀
# 2024-02  5    ▀▀
# 2024-01  1
# 2023-12  36   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-11  86   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-10  58   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-09  7    ▀▀▀▀
# 2023-08  44   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-07  34   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-06  39   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀
# 2023-05  30   ▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀

# %%
# !git log --author="jbrockmendel" --name-only --pretty=format: | sort | uniq
# Out:
# asv_bench/benchmarks/algorithms.py
# asv_bench/benchmarks/algos/__init__.py
# asv_bench/benchmarks/algos/isin.py
# asv_bench/benchmarks/arithmetic.py
# asv_bench/benchmarks/attrs_caching.py
# asv_bench/benchmarks/binary_ops.py
# asv_bench/benchmarks/categoricals.py
# asv_bench/benchmarks/ctors.py
# asv_bench/benchmarks/dtypes.py
# asv_bench/benchmarks/eval.py
# asv_bench/benchmarks/frame_ctor.py
# asv_bench/benchmarks/frame_methods.py
# asv_bench/benchmarks/gil.py
# asv_bench/benchmarks/groupby.py
# asv_bench/benchmarks/hash_functions.py
# asv_bench/benchmarks/index_cached_properties.py
# asv_bench/benchmarks/indexing_engines.py
# asv_bench/benchmarks/indexing.py
# asv_bench/benchmarks/index_object.py
# asv_bench/benchmarks/inference.py
# asv_bench/benchmarks/io/csv.py
# asv_bench/benchmarks/io/excel.py
# asv_bench/benchmarks/io/hdf.py
# asv_bench/benchmarks/io/json.py
# asv_bench/benchmarks/io/msgpack.py
# asv_bench/benchmarks/io/parsers.py
# asv_bench/benchmarks/io/sas.py
# ...

# %%
# !pip install radon
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !git log --pretty=format: --name-only --no-merges | sort | uniq -c | sort -nr | head -20 | tee files-churn.txt
# Out:
#   32931
#    3156 pandas/core/frame.py
#    2105 pandas/core/generic.py
#    2028 pandas/core/series.py
#    1267 pandas/core/indexes/base.py
#    1128 pandas/tests/test_frame.py
#    1072 RELEASE.rst
#     840 doc/source/release.rst
#     828 ci/code_checks.sh
#     780 pandas/io/pytables.py
#     756 pandas/core/index.py
#     722 pandas/core/internals/blocks.py
#     698 pandas/core/indexing.py
#     690 pandas/core/common.py
#     676 pandas/io/parsers.py
#     668 pandas/core/groupby.py
#     659 pandas/core/groupby/groupby.py
#     651 pandas/tests/test_series.py
#     647 setup.py
#     626 pandas/core/internals.py

# %%
# !radon cc src-polars -a -nc
# Out:
#    7287
#     438 setup.py
#     431 WHATSNEW
#     304 test/surface_test.py
#     240 src/surface.c
#     221 test/draw_test.py
#     183 src_c/event.c
#     181 src_c/display.c
#     175 src_c/draw.c
#     172 test/mixer_test.py
#     167 Setup.in
#     163 docs/index.html
#     159 test/display_test.py
#     157 src/mixer.c
#     155 test/font_test.py
#     152 src/display.c
#     145 test/color_test.py
#     141 docs/reST/conf.py
#     139 lib/__init__.py
#     134 test/math_test.py

# %%
# !find src_py -name '*.py' -type f -exec wc -l {} + | sort -rn | head -n 10
# Out:
#   7428 total
#   1813 src_py/sprite.py
#    837 src_py/cursors.py
#    717 src_py/midi.py
#    692 src_py/colordict.py
#    562 src_py/draw_py.py
#    515 src_py/sysfont.py
#    448 src_py/surfarray.py
#    345 src_py/__init__.py
#    271 src_py/threads/__init__.py
